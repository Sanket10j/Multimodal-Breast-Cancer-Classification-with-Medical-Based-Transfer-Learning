# %%
import pandas as pd

# %%
input_path = r'/kaggle/input/bcmid-labels/BCMID_labels.csv'
df = pd.read_csv(input_path)

# %%
df.shape
# Out:
# (320, 3)

# %%
df
# Out:
#       2071y19  BIRADS2  0
# 0     3597y17  BIRADS2  0
# 1     0470y18  BIRADS3  0
# 2     0919y18  BIRADS1  0
# 3     0877y07  BIRADS4  1
# 4    04138y20  BIRADS2  0
# ..        ...      ... ..
# 315   4245y15  BIRADS2  0
# 316  04422y20  BIRADS2  0
# 317   3218y12  BIRADS2  0
# 318  03911y20  BIRADS6  1
# 319   3270y12  BIRADS1  0
#
# [320 rows x 3 columns]

# %%
df.columns = ["id", "birad", "class"]

# %%
df
# Out:
#            id    birad  class
# 0     3597y17  BIRADS2      0
# 1     0470y18  BIRADS3      0
# 2     0919y18  BIRADS1      0
# 3     0877y07  BIRADS4      1
# 4    04138y20  BIRADS2      0
# ..        ...      ...    ...
# 315   4245y15  BIRADS2      0
# 316  04422y20  BIRADS2      0
# 317   3218y12  BIRADS2      0
# 318  03911y20  BIRADS6      1
# 319   3270y12  BIRADS1      0
#
# [320 rows x 3 columns]

# %%
cd = df["class"].value_counts()
cd
# Out:
# class
# 0    275
# 1     45
# Name: count, dtype: int64

# %%
bd = df["birad"].value_counts()
bd
# Out:
# birad
# BIRADS2    172
# BIRADS1     51
# BIRADS3     47
# BIRADS6     20
# BIRADS4     16
# BIRADS5      9
# BIRADS0      5
# Name: count, dtype: int64

# %%
labels_map = dict(zip(df["id"], df["class"]))

# %%
print(labels_map)
# Out:
# {'3597y17': 0, '0470y18': 0, '0919y18': 0, '0877y07': 1, '04138y20': 0, '1780y07': 0, '1238y19': 0, '2889y13': 0, '3679y19': 0, '4105y18': 0, '1636y14': 0, '01566y21': 1, '0072y16': 0, '2515y11': 0, '00506y21': 1, '1864y16': 0, '2462y19': 0, '4856y16': 0, '00717y20': 0, '04902y22': 1, '05439y20': 0, '2995y15': 0, '0505y09': 1, '01262y21': 1, '01698y21': 0, '3052y14': 0, '1193y16': 0, '1362y19': 0, '0103y17': 0, '00472y20': 0, '04583y20': 0, '0331y15': 1, '2429y17': 0, '3761y16': 0, '1859y17': 0, '9207y18': 1, '2880y19': 0, '1800y14': 0, '2758y19': 0, '1352y15': 0, '1000y17': 0, '4315y15': 0, '1322y17': 0, '02962y20': 0, '0546y16': 0, '00278y20': 1, '1724y16': 0, '1275y19': 0, '1400y15': 0, '02922y23': 0, '4908y16': 0, '3604y19': 0, '0646y19': 0, '2215y19': 0, '3384y18': 0, '2629y19': 0, '04412y22': 1, '02299y20': 0, '3399y16': 0, '1473y18': 0, '3915y18': 0, '0178y10': 0, '1291y17': 1, '2092y13': 0, '0829y18': 0, '1899y16': 0, '05891y20': 0, '2386y11': 0, '0193y16': 0, '2829y16': 1, '
# ...
